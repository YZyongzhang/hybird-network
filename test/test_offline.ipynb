# %%
import sys
sys.path.append("/home/getuanhui/project/finnal_exp/")
from network import SAC_model
import torch
from configs.default import get_config
config = get_config()
task_config = config.TASK_CONFIG
train_config = task_config.TRAIN
offline_config  = train_config.OFFLINE
state_dim = offline_config.state_dim
action_dim = offline_config.action_dim
hidden_dim = offline_config.hidden_dim
lr = offline_config.lr
target_entropy = offline_config.target_entropy  
tau = offline_config.tau
gamma = offline_config.gamma

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
sac_model = SAC_model(
    state_dim=state_dim,
    hidden_dim=hidden_dim,
    action_dim=action_dim,
    actor_lr=lr,
    critic_lr=lr,
    alpha_lr=lr,
    target_entropy=target_entropy,
    tau=tau,
    gamma=gamma,
    beta=1,
    device=device
)
# Out:
# 2025-10-21 16:26:58.115322: I tensorflow/core/util/port.cc:111] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-10-21 16:26:58.133816: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-10-21 16:26:58.133832: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-10-21 16:26:58.133841: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-10-21 16:26:58.137368: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-10-21 16:26:58.469182: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
path = '../experiment/ckpt/offline/Foundation_model_90.pth'
sac_model.load_state_dict(torch.load(path))
# Out:
# <All keys matched successfully>

# %%
sac_model.eval()
# Out:
# SAC_model(
#   (actor): PolicyNet(
#     (fc1): Linear(in_features=256, out_features=128, bias=True)
#     (fc2): Linear(in_features=128, out_features=4, bias=True)
#   )
#   (critic_1): QValueNet(
#     (fc1): Linear(in_features=256, out_features=128, bias=True)
#     (fc2): Linear(in_features=128, out_features=4, bias=True)
#   )
#   (critic_2): QValueNet(
#     (fc1): Linear(in_features=256, out_features=128, bias=True)
#     (fc2): Linear(in_features=128, out_features=4, bias=True)
#   )
#   (target_critic_1): QValueNet(
#     (fc1): Linear(in_features=256, out_features=128, bias=True)
#     (fc2): Linear(in_features=128, out_features=4, bias=True)
#   )
#   (target_critic_2): QValueNet(
#     (fc1): Linear(in_features=256, out_features=128, bias=True)
#     (fc2): Linear(in_features=128, out_features=4, bias=True)
#   )
# )
